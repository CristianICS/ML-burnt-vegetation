# %% [markdown]
# # Inspecting the Independent Variables
#
# :::
# The current notebook does not examine the Landsat-related variables captured during `summer_long` period. These predictors were computed to construct a specific model for additional fires, excluding spring values due to image issues such as high cloud cover.
# :::
#
# The goal is to select the best predictor variables, i.e., those that most effectively distinguish between vegetation types.
#
# The data are examined using the three available label sets. Each set has a **different number of labels**.
#
# > Note: The `aspect` predictor has not been used.

# %%
from imblearn.under_sampling import RandomUnderSampler
from sklearn.decomposition import PCA # type: ignore
from sklearn.preprocessing import StandardScaler # type: ignore
from matplotlib import pyplot as plt # type: ignore
from matplotlib.patches import Patch
from pathlib import Path
import os
import numpy as np # type: ignore
import pandas as pd # type: ignore
import geopandas as gpd # type: ignore

# %%
ROOT = Path.cwd().resolve().parent

dataset = gpd.read_file(Path(ROOT, "results/dataset.csv"))
label_codes = pd.read_csv(Path(ROOT, "data/labels/label_codes.csv"))

# %% [markdown]
# Join the table of predictors with the table of label names representing the classified vegetation types.

# %%
# Try to convert stringified numeric columns back to numeric
for col in dataset.select_dtypes(include="object").columns:
    try:
        dataset[col] = pd.to_numeric(dataset[col])
    except:
        pass

# Keep 'code_ifn' out (to avoid dropping valid data via dropna)
label_codes= label_codes.loc[:, label_codes.columns != 'code_ifn']
dataset = dataset.join(label_codes.set_index("code_v1"), on="ESPE")
# Remove Pinus uncinata (excluded due to the small number of labels)
dataset = dataset.query("(code_v1_reclass != 5) & (code_v1_reclass != 15)")

# %% [markdown]
# The notebook includes several graphics. These graphics can be saved in the directory specified by the `graphics_path` variable.

# %%
graphics_path = Path(ROOT, "figures")

# %% [markdown]
# ## Data Inspection
#
# First, verify that the predictor variables are in a valid numerical format.

# %%
global_pred = ["aspect", "dem", "shadow", "slope", "acibasi"]
pred_vars = (
    dataset.columns.str.endswith("summer")
    | dataset.columns.str.endswith("spring")
    | dataset.columns.isin(global_pred)
)

# %%
dataset.loc[:, pred_vars].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14198 entries, 0 to 14201
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   coastal_spring  11918 non-null  float64
#  1   blue_spring     11929 non-null  float64
#  2   green_spring    11991 non-null  float64
#  3   red_spring      11984 non-null  float64
#  4   nir_spring      11991 non-null  float64
#  5   swir1_spring    11991 non-null  float64
#  6   swir2_spring    11984 non-null  float64
#  7   coastal_summer  13433 non-null  float64
#  8   blue_summer     13442 non-null  float64
#  9   green_summer    13478 non-null  float64
#  10  red_summer      13474 non-null  float64
#  11  nir_summer      13478 non-null  float64
#  12  swir1_summer    13478 non-null  float64
#  13  swir2_summer    13474 non-null  float64
#  14  aspect          14198 non-null  float64
#  15  dem             14198 non-null  float64
#  16  shadow          14198 non-null  float64
#  17  slope           14198 non-null  float64
#  18  acibasi         14198 non-null  float64
# dtypes: float64(19)
# memory usage: 2.2 MB

# %% [markdown]
# All variables have the correct data type. However, some columns contain invalid values:
#
# - **Landsat bands**: Negative values are associated with erroneous pixels.
# - **aspect**: Values below 0 are invalid.
# - **acibasi**: The value `-9999` corresponds to missing data.
# - **slope**: Negative values should not exist.
#
# For this reason, values below zero are transformed to `NaN`.
# This ensures that rows can be removed later if the corresponding dataset version makes use of the predictor variable.

# %%
dataset.loc[:, pred_vars].describe()
# Out:
#        coastal_spring   blue_spring  green_spring    red_spring    nir_spring  \
# count    11918.000000  11929.000000  11991.000000  11984.000000  11991.000000
# mean       720.820583    813.340209   1146.007141   1365.562562   2414.754310
# std        441.627570    488.991826    596.571552    746.861051    683.759214
# min          3.000000      7.000000     18.000000     49.000000    151.000000
# 25%        372.187500    414.000000    633.000000    694.916675   1882.000000
# 50%        690.500000    776.500000   1095.000000   1339.333300   2313.000000
# 75%        987.000000   1123.750000   1566.125000   1926.416700   2869.583350
# max       5826.000000   3996.000000   4335.000000   4613.000000   7519.333500
#
#        swir1_spring  swir2_spring  coastal_summer   blue_summer  green_summer  \
# count  11991.000000  11984.000000    13433.000000  13442.000000  13478.000000
# mean    2705.306582   1994.756734      807.006199    931.750391   1355.580409
# std     1149.148119   1011.704114      473.141414    548.433975    700.081115
# min        3.000000     19.000000        4.000000      8.000000     38.000000
# 25%     1698.000000   1094.500000      393.000000    447.083335    723.000000
# 50%     2743.000000   2001.000000      752.000000    873.475000   1296.000000
# 75%     3611.000000   2785.083325     1166.500000   1352.000000   1907.687500
# max     7697.000000   6664.000000     3490.000000   3892.000000   4837.000000
#
#          red_summer    nir_summer  swir1_summer  swir2_summer        aspect  \
# count  13474.000000  13478.000000  13478.000000  13474.000000  14198.000000
# mean    1644.866545   2861.621234   3170.852623   2359.051602    104.782830
# std      934.180192    716.559519   1326.321244   1204.450589    885.918674
# min       65.000000    117.000000    125.000000    158.000000  -9999.000000
# 25%      774.000000   2281.000000   1974.125000   1259.083350     99.251778
# 50%     1607.500000   2767.000000   3211.000000   2390.925000    186.571564
# 75%     2413.075000   3378.875000   4299.458375   3345.500000    257.352417
# max     5721.000000   6692.000000   8114.000000   6843.000000    549.714355
#
#                 dem        shadow         slope       acibasi
# count  14198.000000  14198.000000  14198.000000  14198.000000
# mean     834.862516    171.098535     15.123520  -1662.582758
# std      345.130060     41.574803      9.898179   3724.193234
# min      108.000000      0.000000     -0.352233  -9999.000000
# 25%      545.250000    148.000000      7.960265      1.000000
# 50%      911.000000    179.000000     13.855948      1.000000
# 75%     1067.000000    198.000000     20.754133      1.000000
# max     2838.000000    255.000000     79.123726      2.000000

# %%
# Make a copy to avoid modifying the original dataset in place
dat = dataset.copy()

# Replace values < 0 with 0 (nodata value) in the masked columns only
dat.loc[:, pred_vars] = (
    dat.loc[:, pred_vars]
    .where(dat.loc[:, pred_vars] >= 0, 0)
)

# %% [markdown]
# > **Note:** Some columns without negative values use 0 as their minimum because missing values (`NA`) were replaced with 0.

# %%
dat.loc[:, pred_vars].describe()
# Out:
#        coastal_spring   blue_spring  green_spring    red_spring    nir_spring  \
# count    14198.000000  14198.000000  14198.000000  14198.000000  14198.000000
# mean       605.066890    683.359300    967.866716   1152.620210   2039.394205
# std        483.483701    538.263214    687.749773    846.328608   1077.222479
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        202.000000    232.000000    439.000000    451.000000   1657.625000
# 50%        582.000000    649.000000    918.000000   1081.000000   2135.000000
# 75%        924.875000   1054.000000   1475.312550   1817.375000   2753.625025
# max       5826.000000   3996.000000   4335.000000   4613.000000   7519.333500
#
#        swir1_spring  swir2_spring  coastal_summer   blue_summer  green_summer  \
# count  14198.000000  14198.000000    14198.000000  14198.000000  14198.000000
# mean    2284.781746   1683.699444      763.524037    882.137538   1286.837072
# std     1440.878650   1178.002043      494.976818    573.176706    744.127135
# min        0.000000      0.000000        0.000000      0.000000      0.000000
# 25%     1218.250000    696.500000      347.666660    400.500000    664.541675
# 50%     2325.000000   1631.000000      698.166650    813.250000   1213.416700
# 75%     3460.500025   2653.000000     1145.000000   1326.937500   1878.000000
# max     7697.000000   6664.000000     3490.000000   3892.000000   4837.000000
#
#          red_summer    nir_summer  swir1_summer  swir2_summer        aspect  \
# count  14198.000000  14198.000000  14198.000000  14198.000000  14198.000000
# mean    1560.989704   2716.504507   3010.054349   2238.756254    180.313211
# std      979.350960    938.965168   1467.637423   1282.985267     98.910283
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      682.083325   2215.000000   1800.000000   1089.625000     99.251778
# 50%     1492.083300   2710.450000   3038.166650   2248.416650    186.571564
# 75%     2375.249975   3344.000000   4258.500000   3303.458325    257.352417
# max     5721.000000   6692.000000   8114.000000   6843.000000    549.714355
#
#                 dem        shadow         slope       acibasi
# count  14198.000000  14198.000000  14198.000000  14198.000000
# mean     834.862516    171.098535     15.123674      0.865474
# std      345.130060     41.574803      9.897942      0.424396
# min      108.000000      0.000000      0.000000      0.000000
# 25%      545.250000    148.000000      7.960265      1.000000
# 50%      911.000000    179.000000     13.855948      1.000000
# 75%     1067.000000    198.000000     20.754133      1.000000
# max     2838.000000    255.000000     79.123726      2.000000

# %%
dat.loc[:, pred_vars].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14198 entries, 0 to 14201
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   coastal_spring  14198 non-null  float64
#  1   blue_spring     14198 non-null  float64
#  2   green_spring    14198 non-null  float64
#  3   red_spring      14198 non-null  float64
#  4   nir_spring      14198 non-null  float64
#  5   swir1_spring    14198 non-null  float64
#  6   swir2_spring    14198 non-null  float64
#  7   coastal_summer  14198 non-null  float64
#  8   blue_summer     14198 non-null  float64
#  9   green_summer    14198 non-null  float64
#  10  red_summer      14198 non-null  float64
#  11  nir_summer      14198 non-null  float64
#  12  swir1_summer    14198 non-null  float64
#  13  swir2_summer    14198 non-null  float64
#  14  aspect          14198 non-null  float64
#  15  dem             14198 non-null  float64
#  16  shadow          14198 non-null  float64
#  17  slope           14198 non-null  float64
#  18  acibasi         14198 non-null  float64
# dtypes: float64(19)
# memory usage: 2.2 MB

# %%
# Remove columns with nodata values
dat = dat[(dat.loc[:, pred_vars] != 0).all(axis=1)]

# %%
dat.loc[:, pred_vars].describe()
# Out:
#        coastal_summer  blue_summer  green_summer   red_summer   nir_summer  \
# count     6462.000000  6462.000000   6462.000000  6462.000000  6462.000000
# mean       782.951667   900.616482   1295.835705  1518.604522  2796.239879
# std        527.645577   607.503460    762.865464  1003.383228   749.994055
# min         11.000000    10.000000    168.000000    65.000000   608.500000
# 25%        327.233333   377.541667    633.000000   622.000000  2186.375000
# 50%        578.750000   648.833333    982.500000  1140.500000  2636.750000
# 75%       1231.916667  1419.750000   1957.500000  2441.812500  3358.937500
# max       4912.000000  3582.000000   4195.666667  5029.333333  6148.000000
#
#        swir1_summer  swir2_summer  coastal_spring  blue_spring  green_spring  \
# count   6462.000000   6462.000000     6462.000000  6462.000000   6462.000000
# mean    2906.099027   2093.531726      692.660731   768.503978   1064.090412
# std     1372.330864   1237.030911      526.144919   543.890954    630.494461
# min      451.000000    158.000000        9.000000    25.000000     66.333333
# 25%     1680.083333    956.812500      283.000000   316.125000    522.000000
# 50%     2539.875000   1766.250000      607.000000   660.500000    889.000000
# 75%     4213.583333   3239.875000      998.000000  1132.000000   1545.000000
# max     7138.000000   6115.000000    10906.000000  6915.000000   4335.000000
#
#         red_spring   nir_spring  swir1_spring  swir2_spring       aspect  \
# count  6462.000000  6462.000000   6462.000000   6462.000000  6462.000000
# mean   1227.120794  2278.878142   2426.287675   1725.949948   192.951696
# std     776.396638   667.859641   1193.714109   1024.881717   100.763295
# min      41.000000   170.000000    130.666667     48.500000     0.000100
# 25%     552.750000  1783.125000   1401.250000    828.000000   104.415398
# 50%     990.750000  2107.833333   2142.250000   1453.000000   207.911850
# 75%    1877.000000  2726.500000   3454.750000   2600.000000   275.261642
# max    4572.000000  5507.000000  13335.000000   6363.000000   405.660309
#
#                dem       shadow        slope      acibasi
# count  6462.000000  6462.000000  6462.000000  6462.000000
# mean    829.114516   169.003405    15.292881     1.053544
# std     306.954538    38.679740     9.029982     0.225133
# min     108.000000     1.000000     0.006603     1.000000
# 25%     592.000000   146.000000     8.432046     1.000000
# 50%     874.000000   175.000000    14.730375     1.000000
# 75%    1041.000000   195.000000    21.445545     1.000000
# max    1827.000000   254.000000    77.194717     2.000000

# %% [markdown]
# To obtain a more balanced dataset, most of the labels corresponding to sparse vegetation were removed, leaving a number of cases similar to that of the second most frequent label.

# %%
def bg_undersampling(df):
    """Perform a reduction in the very high bare ground number of labels"""
    X = df.drop(columns=['ESPE_rc'])
    y = df['ESPE_rc']

    # Find the sparse vegetation class
    max_clss = y.value_counts().idxmax()
    # Define the undersampler
    rus = RandomUnderSampler(
        sampling_strategy={max_clss: 800},
        random_state=42
    )

    # Apply undersampling
    X_resampled, y_resampled = rus.fit_resample(X, y)

    # Create new dataframe. This is mandatory to remove NA values in each
    # predictor set iteration and remove the ESPE codes related to them
    dataset = pd.concat([
        X_resampled.reset_index(drop=True),
        y_resampled.reset_index(drop=True)],
        axis=1
    )

    return dataset

dat = bg_undersampling(dat)

# %%
dat.loc[:, pred_vars].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5649 entries, 0 to 5648
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   blue_spring         5649 non-null   float64
#  1   green_spring        5649 non-null   float64
#  2   red_spring          5649 non-null   float64
#  3   nir_spring          5649 non-null   float64
#  4   swir1_spring        5649 non-null   float64
#  5   swir2_spring        5649 non-null   float64
#  6   coastal_summer      5649 non-null   float64
#  7   blue_summer         5649 non-null   float64
#  8   green_summer        5649 non-null   float64
#  9   red_summer          5649 non-null   float64
#  10  nir_summer          5649 non-null   float64
#  11  swir1_summer        5649 non-null   float64
#  12  swir2_summer        5649 non-null   float64
#  13  coastal_summerlong  5380 non-null   float64
#  14  dem                 5649 non-null   float64
#  15  shadow              5649 non-null   float64
#  16  slope               5649 non-null   float64
#  17  acibasi             5649 non-null   float64
#  18  code_v1_reclass     5649 non-null   int64
# dtypes: float64(18), int64(1)
# memory usage: 838.7 KB

# %% [markdown]
# ### Create NDVI

# %%
def ndvi(df, suffix):
    numerator = df[f"nir_{suffix}"] - df[f"red_{suffix}"]
    denominator = df[f"nir_{suffix}"] + df[f"red_{suffix}"]
    return numerator / denominator

dat["NDVI_summer"] = ndvi(dat, "summer")
dat["NDVI_spring"] = ndvi(dat, "spring")
dat["NDVI_summerlong"] = ndvi(dat, "summerlong")

# %% [markdown]
# ## Outliers
#
# After generating a Cleveland dot plot (Cleveland, 1993), the following anomalous values were observed:
#
# - **NDVI**: Values below 0, typically associated with water, snow, clouds, or certain artificial surfaces.
# - **SWIR1 (spring)**: Values very close to or greater than 1, likely due to Landsat band errors or cloud contamination.
#
# All other values appear to fall within the expected ranges and accurately represent the land cover types.

# %%
# Boxplots of predictor variables
lcols = (
    dat.columns[dat.columns.str.endswith("summer")].to_list() +
    dat.columns[dat.columns.str.endswith("spring")].to_list()
)
gcols = ['dem', 'shadow', 'slope', 'acibasi']

def print_dotplot(df, sorted_idx, col, ax, legend_groups):

    for group_name, group_dict in legend_groups.items():
        
        sorted_values = df.iloc[sorted_idx].query(group_dict["query"])[col]
    
        # Cleveland dotplot
        ax.plot(
            sorted_values,
            range(len(sorted_values)),
            "o",
            color=group_dict["color"])
    
    # Formatting
    ax.set_xlabel("Value")
    ax.set_ylabel("Observation (sorted index)")
    ax.grid(True, axis="x", linestyle="--", alpha=0.6)
    ax.set_title(col)

def dotplot_figure(df, lcols, gcols, nrows, ncols, output_path=None):

    fig, axs = plt.subplots(nrows, ncols, figsize = (10,10), sharey=True)

    # Transform landsat bands to reflectance
    pattern =  fr'^(?!NDVI_).*(?:spring|summer)$'
    target_bands = df.columns.str.contains(pattern)
    df_ref = df.copy()
    df_ref.loc[:, target_bands] = df_ref.loc[:, target_bands] / 10000

    # df_v = df_ref.query(dat_queries[version])
    # Select the first column to plot
    values = df_ref["dem"]
    # Sort values for readability
    sorted_idx = values.argsort()

    # Store plot styles to create the graph legend
    leg_groups = {
        "Sparse vegetation": {"color": "#ACACAC", "query": "ESPE_rc == 20"},
        "Tree": {"color": "#666B6F", "query": "ESPE_rc < 10"},
        "Shrub": {"color": "#212529", "query": "(ESPE_rc > 10) and (ESPE_rc < 20)"}
    }

    for n, df_col in enumerate(lcols + gcols):

        # Integer division
        row = n // ncols
        # Division Remainder
        col = n % ncols

        print_dotplot(df_ref, sorted_idx, df_col, axs[row, col], leg_groups)

    # Create a global legend
    leg_handles, leg_labels = [], []
    for label, properties in leg_groups.items():
        leg_handles.append(
            axs[0, 0].plot(
                [], [],
                # marker="o",
                color=properties['color'],
                linewidth=2,
                label=label
            )[0]
        )
        leg_labels.append(label)

    # Add global legend
    fig.legend(leg_handles, leg_labels, loc='lower center', ncol=8, title='')
    # Adjust layout to fit global legend
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])

    if output_path is not None:
        plt.savefig(output_path)

# %%
nrows = 4
ncols = 5

# outpath = Path(graphics_path, "cleveland_plot.svg")
dotplot_figure(dat, lcols, gcols, nrows, ncols)

# %%
def drop_outliers(df):
    target = df.copy()
    target.query("acibasi != 0", inplace=True)
    # Likely water, snow, clouds, or some artificial surfaces.
    target.query("(NDVI_summer > 0) and (NDVI_spring > 0)", inplace=True)
    # Likely clouds or Landsat 7 errors
    # Note: the plot is displaying reflectances but the real values are
    # integers with an applied constant of 10000
    target.query("swir1_spring < 9000", inplace=True)
    target.query("coastal_spring < 9000", inplace=True)
    return target

dat[["NDVI_summer", "NDVI_spring", "swir1_spring", "coastal_spring"]].describe()
# Out:
#        NDVI_summer  NDVI_spring  swir1_spring  coastal_spring
# count  5425.000000  4737.000000   5649.000000     5649.000000
# mean      0.503642     0.469415   1515.038267      420.152452
# std       0.196703     0.177481   1033.712467      476.018052
# min      -0.030677    -0.276855      0.000000        0.000000
# 25%       0.365507     0.353474    967.000000      116.000000
# 50%       0.521852     0.480848   1425.400000      293.000000
# 75%       0.653465     0.599509   2012.000000      558.500000
# max       1.000000     1.000000   6355.333500     5826.000000

# %%
drop_outliers(dat)[["NDVI_summer", "NDVI_spring", "swir1_spring"]].describe()
# Out:
#        NDVI_summer  NDVI_spring  swir1_spring
# count  4570.000000  4570.000000   4570.000000
# mean      0.498306     0.469841   1802.193444
# std       0.191430     0.175002    848.922953
# min       0.001690     0.039000      3.000000
# 25%       0.368232     0.354943   1199.875000
# 50%       0.513715     0.480761   1593.000000
# 75%       0.641463     0.598881   2156.850000
# max       1.000000     1.000000   6243.000000

# %%
dat_without_out = drop_outliers(dat)

# %%
nrows = 4
ncols = 5

# outpath = Path(graphics_path, "cleveland_plot.svg")
dotplot_figure(dat_without_out, lcols, gcols, nrows, ncols)

# %% [markdown]
# ## Versions
#
# There are three different training datasets, or versions of the original dataset.

# %%
dat_queries = {1: "(source == 'Digitized') | (source == 'SIOSE')"}
dat_queries[2] = f"(FCC > 20) & (Ocu1 > 4) | ({dat_queries[1]})"
dat_queries[3] = f"(FCC > 20) & (Ocu1 > 6) | ({dat_queries[1]})"

# %%
# Count of each class
bbox_label_groups = {
    r"$\it{Pinus\ halepensis}$": [1, 11],
    r"$\it{Pinus\ nigra}$": [2, 12],
    r"$\it{Pinus\ pinaster}$": [3, 13],
    r"$\it{Pinus\ sylvestris}$": [4, 14],
    # r"$\it{Pinus\ uncinata}$": [5],
    r"$\it{Quercus}\ g.\ \it{cerrioides}$": [6, 16],
    r"$\it{Quercus\ ilex}$": [7, 17]
}

species = list(bbox_label_groups.keys())
tree_groups = [g[0] for g in bbox_label_groups.values()]
shrub_groups = [g[1] for g in bbox_label_groups.values()]

# Dictionary to store groups which have been the bar levels
leg_dict = {
    "Shrub": {"group": shrub_groups, "color": "#212529"},
    "Tree": {"group": tree_groups, "color": "#ced4da"}
}

height = 0.6  # the thickness of the bars

# One plot by dataset version
fig, axs = plt.subplots(1, 3, figsize=(8, 4), sharey=True, sharex=True)

for v in range(3):

    dat_i = dat_without_out.query(dat_queries[v+1])

    # Spaces between bars
    left = np.zeros(len(species))

    for i, (lab, lab_group) in enumerate(leg_dict.items()):

        group, color = lab_group.values()
        query = f"code_v1_reclass in [{','.join([str(v) for v in group])}]"
        d = dat_i.query(query)
        d_group = d.groupby(["code_v1_reclass"]).count()["ESPE"].sort_index()
        sp_count = d_group.values

        axs[v].barh(species, sp_count, height=height, color=color, left=left)
        # Add the next group of bars on top of the last ones
        left += sp_count

        axs[v].set_title(f"Dataset {v+1}")

    # Add sparse vegetation
    sv_value = (
        dat_i.query("code_v1_reclass == 20")
        .groupby(["code_v1_reclass"])
        .count()["ESPE"]
    )
    axs[v].barh(
        "Sparse veg.", sv_value.iloc[0], color=leg_dict["Shrub"]["color"])

# Create empty lists to store legend handles (colored patches) and labels
leg_handles, leg_labels = [], []

# Loop over category names and their associated colors
for label, l_dict in leg_dict.items():

    # Create a dummy colored patch for the legend
    # (no need to actually plot bars — just create a representative box)
    leg_handles.append(Patch(facecolor=l_dict["color"], label=label))

    # Store the corresponding label for later use
    leg_labels.append(label)

# Create a global legend at the bottom of the figure
# - `leg_handles`: list of patches to show in the legend
# - `leg_labels`: corresponding text labels
# - `loc='best'`: place legend in the best position according to pyplot
# - `ncol=1`: ensure vertical layout
# - `title=''`: no legend title
fig.legend(leg_handles, leg_labels, loc='lower center', ncol=2, title='')
fig.tight_layout(rect=[0, 0.03, 1, 0.95])

# plt.savefig(Path(graphics_path, f"labels_distribution.svg"))

# %%
print(
    dat_without_out.query(dat_queries[v+1]).groupby(["label_reclass"])
    .count()["ESPE"].to_latex()
)
# Out:
# \begin{tabular}{lr}
# \toprule
#  & ESPE \\
# label_reclass &  \\
# \midrule
# Pinus halepensis & 713 \\
# Pinus nigra & 307 \\
# Pinus pinaster & 135 \\
# Pinus sylvestris & 470 \\
# Quercus g. cerrioides & 179 \\
# Quercus ilex & 376 \\
# S. Mediterranean pine & 75 \\
# S. Pinus nigra & 87 \\
# S. Pinus pinaster & 58 \\
# S. Pinus sylvestris & 164 \\
# S. Quercus g. cerrioides & 34 \\
# S. Quercus ilex & 51 \\
# Sparse vegetation & 493 \\
# \bottomrule
# \end{tabular}

# %%
# One plot by dataset version
fig, axs = plt.subplots(1, 3, figsize=(8, 3), sharey=True, sharex=True)

for v in range(1, 4):
    dat_i = dat.query(dat_queries[v])
    # Counting the species values giving the label source
    grpd = dat_i.groupby(["source"]).count()["ESPE"]
    # Temporal fix to the fact that dataset 1 only contains 2 labels
    if v == 1:
        new_rows = pd.Series([0] * 3, index=[f"NFI{i}" for i in range(2,5)])
        grpd = pd.concat([grpd, new_rows])
    
    (grpd
        .sort_index()
        .plot(kind='barh', color="grey", ax=axs[v-1], title=f"Dataset {v}")
    )

fig.tight_layout()

# %%
import matplotlib.colors as mcolors

# One plot by dataset version
fig, axs = plt.subplots(1, 3, figsize=(8, 3), sharey=True, sharex=True)

dataset_sources = pd.unique(dat["source"])
years = sorted(pd.unique(dat["YEAR"]))
height = 0.6  # the thickness of the bars

# Create a colormap from grayscale colors
cmap = mcolors.LinearSegmentedColormap.from_list(
    "custom_grey",
    ["#bbbcbd", "#212529"],
    len(years)
)
colors = [cmap(i) for i in range(cmap.N)]
year_to_color = {year: colors[i] for i, year in enumerate(years)}

for v in range(1, 4):
    left = np.zeros(len(dataset_sources))

    dat_i = dat.query(dat_queries[v])

    for i, year in enumerate(years):

        if year not in pd.unique(dat_i["YEAR"]):
            continue
        query = f"YEAR == {year}"
        d = dat_i.query(query)
        d_group = d.groupby(["source"]).count()["ESPE"]
        # Not all the years contain the same sources
        # Add the current year values to a pandas of the sources with join
        temp_pd = pd.concat([
            pd.Series([0]*len(dataset_sources), index=dataset_sources),
            pd.Series(d_group.values, index=d_group.index, name="data"),
        ], axis=1).fillna(0).sort_index()
        axs[v-1].barh(
            temp_pd.index,
            temp_pd["data"],
            height=height,
            color=year_to_color[year],
            left=left)
        # Add the next group of bars on top of the last ones
        left += temp_pd["data"]

        axs[v-1].set_title(f"Dataset {v}")
        axs[v-1].set_xlim((0, 1200))

# ---- Gradient Legend ----
# Normalize years to the range [0,1] for color mapping
norm = mcolors.Normalize(vmin=min(years), vmax=max(years))

# Add a colorbar to illustrate the gradient
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # only needed for matplotlib < 3.2

cbar = fig.colorbar(
    sm,
    ax=axs,
    orientation="horizontal",
    fraction=0.05,
    pad=0.1
)
cbar.set_label("Year")
# fig.tight_layout(rect=[0, 0.02, 1, 0.95])
# plt.savefig(Path(graphics_path, f"dataset_versions.svg"))

# %% [markdown]
# ## Behavior of Predictor Variables
#
# For each dataset version, an analysis of the predictor variables was carried out. All three versions of the dataset exhibit an imbalanced sample distribution.

# %% [markdown]
# ### Landsat bands

# %%
def ref_plot(df, version):
    # Transform values to reflectance in order to get
    # a better representation of the spec. sign.
    lcols = (
        df.columns.str.endswith("summer")
        | df.columns.str.endswith("spring")
    )

    dat_ref = df.copy().query(dat_queries[version])
    dat_ref.loc[:, lcols] = dat_ref.loc[:, lcols] / 10000

    # Compute plots by tree, shrub and bare ground
    spectral_sign_splits = {
        'Trees': [1, 2, 3, 4, 6, 7],
        'Shrubs': [11, 12, 13, 14, 16, 17],
        'Bare soil': [20]
    }

    # Three rows (summer, spring and summer long) and three cols
    # (three spectral signature split types).
    fig, axs = plt.subplots(2, 3, sharey=True, sharex=True, figsize=(13,8))

    veg_styles = {
        # Obligate seeders
        r"$\it{Pinus\ halepensis}$": {'color': "#525252", 'linestyle': '-'},
        r"$\it{Pinus\ pinaster}$": {'color': "#969696", 'linestyle': '-'},
        # Passive defense systems
        r"$\it{Pinus\ nigra}$": {'color': "#525252", 'linestyle': '-.'},
        r"$\it{Pinus\ sylvestris}$": {'color': "#969696", 'linestyle': '-.'},
        # 'Pinus uncinata': {'color': "#cccccc", 'linestyle': '-.'},
        # Obligate resprouters
        r"$\it{Quercus}\ g.\ \it{cerrioides}$": {'color': "#525252", 'linestyle': '--'},
        r"$\it{Quercus\ ilex}$": {'color': "#969696", 'linestyle': '--'}
    }

    shrub_styles = veg_styles.copy()
    # Remove the Pinus uncinata
    # del shrub_styles['Pinus uncinata']

    bare_g_style = {
        "Sparse vegetation": {'color': "#212529", "linestyle": "-"}
    }

    for i, (ss_name, ss_codes) in enumerate(spectral_sign_splits.items()):

        if len(ss_codes) > 1:
            q = f"code_v1_reclass in ({",".join(map(str, ss_codes))})"
        else:
            q = f"code_v1_reclass == 20"

        if ss_name == "Trees":
            styles = veg_styles
        elif ss_name == "Shrubs":
            styles = shrub_styles
        else:
            styles = bare_g_style

        df = dat_ref.query(q)

        # Summerlong values are the same as summer
        for z, season in enumerate(["spring", "summer"]):

            pattern =  fr'^(?!NDVI_).*{season}$'

            plot_cols = df.columns[df.columns.str.contains(pattern)].to_list()
            grp = df[
                plot_cols + ["label_reclass"]].groupby('label_reclass').mean()

            # Extract band names without season suffix
            plot_cols = [c.split("_")[0] for c in plot_cols]
            for e, (label_values, row) in enumerate(grp.iterrows()):

                axs[z, i].plot(
                    plot_cols,
                    row,
                    # marker="o",
                    label=label_values,
                    color= [d['color'] for d in styles.values()][e],
                    linestyle = [d['linestyle'] for d in styles.values()][e]
                )

                axs[z, i].set_xlabel("Wavelength")
                axs[z, i].set_ylabel(f"Ref. {season}")
                axs[z, i].grid(True)


    # Create a global legend
    leg_handles, leg_labels = [], []
    for label, properties in {**veg_styles, **bare_g_style}.items():
        leg_handles.append(
            axs[0, 0].plot(
                [], [],
                # marker="o",
                color=properties['color'],
                linestyle=properties['linestyle'],
                label=label
            )[0]
        )
        leg_labels.append(label)

    # Add global legend
    fig.legend(leg_handles, leg_labels, loc='lower center', ncol=8, title='')
    # Adjust layout to fit global legend
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
ref_plot(dat, 1)

# %%
ref_plot(dat, 2)

# %%
ref_plot(dat, 3)

# %% [markdown]
# #### Spectral signatures miniplots
#
# Generate small plots showing the spectral signature of a species and its shrubland.

# %%
def ref_mini_plot(df, tree, shrub, outpath = None):
    # Transform values to reflectance in order to get
    # a better representation of the spec. sign.
    lcols = (
        df.columns.str.endswith("summer")
        | df.columns.str.endswith("spring")
    )
    dat_ref = df.copy()
    dat_ref.loc[:, lcols] = df.loc[:, lcols] / 10000

    # Three rows (summer, spring and summer long) and three cols
    # (three spectral signature split types).
    fig, ax = plt.subplots(1, 1, figsize=(3,3))

    # Summer signature
    pattern =  fr'^(?!NDVI_).*summer$'
    plot_cols = dat_ref.columns[dat_ref.columns.str.contains(pattern)]
    plot_reduced_cols = plot_cols.to_list() + ["label_reclass"]
    
    # Tree spectre
    q = f"code_v1_reclass == {tree}"
    dat_ref_tree = dat_ref.query(q)
    grp = dat_ref_tree[plot_reduced_cols].groupby('label_reclass').mean()
    tree_vals = grp.iloc[0, :].values
    # Shrub spectre
    q = f"code_v1_reclass == {shrub}"
    dat_ref_shrub = dat_ref.query(q)
    grp = dat_ref_shrub[plot_reduced_cols].groupby('label_reclass').mean()
    shrub_vals = grp.iloc[0,:].values

    # Extract band names without season suffix
    plot_col_names = ["C", "B", "G", "R", "N", "SW1", "SW2"]

    ax.plot(
        plot_col_names,
        tree_vals,
        marker="o",
        linestyle="-",
        label="Tree",
        color= "#525252"
    )

    ax.plot(
        plot_col_names,
        shrub_vals,
        marker="o",
        label="Shrub",
        linestyle="--",
        color= "#525252"
    )

    # ax.set_xlabel("Wavelength")
    ax.set_ylabel("Average summer reflectance")
    ax.grid(True)
    ax.set_ylim(0, .4)
    ax.set_yticks((0, .1, .2, .3, .4))

    # Create a global legend
    leg_handles, leg_labels = [], []
    for label, linestyle in zip(["Tree", "Shrub"], ["-", "--"]):
        leg_handles.append(
            ax.plot(
                [], [],
                # marker="o",
                color="#525252",
                linestyle=linestyle,
                label=label
            )[0]
        )
        leg_labels.append(label)

    # Add global legend
    # fig.legend(leg_handles, leg_labels, loc='lower center', ncol=8, title='')
    # Adjust layout to fit global legend
    # fig.tight_layout(rect=[0, 0.04, 1, 0.95])
    fig.tight_layout()

    if outpath is not None:
        plt.savefig(Path(outpath, f"ref_miniplot_{tree}_vs_{shrub}.svg"))

# %%
for i in [1, 2, 3, 4, 6, 7]:
    ref_mini_plot(dat_without_out.query(dat_queries[1]), i, i+10)

# %% [markdown]
# ### Global Predictors and Indices

# %%
nrows = 2
ncols = 3

# Function to color boxplot
def set_box_colors(bp, colors):
    for patch in bp['boxes']:
        patch.set(color=colors["box"])
    for whisker in bp['whiskers']:
        whisker.set(color=colors["whisker"], linewidth=1.5)
    for cap in bp['caps']:
        cap.set(color=colors["cap"], linewidth=1.5)
    for median in bp['medians']:
        median.set(color=colors["median"], linewidth=2)
    for flier in bp['fliers']:
        flier.set(
            markerfacecolor=colors["flier"],
            markeredgecolor=colors["flier"],
            marker='o',
            alpha=1
        )

def create_boxplot(df, pred_vars, ncols, nrows):

    fig, axs = plt.subplots(nrows, ncols, figsize=(15, 10), sharey=True)

    bbox_label_groups = {
        r"$\it{Pinus\ halepensis}$": [1, 11],
        r"$\it{Pinus\ nigra}$": [2, 12],
        r"$\it{Pinus\ pinaster}$": [3, 13],
        r"$\it{Pinus\ sylvestris}$": [4, 14],
        # r"$\it{Pinus\ uncinata}$": [5],
        r"$\it{Quercus}\ g.\ \it{cerrioides}$": [6, 16],
        r"$\it{Quercus\ ilex}$": [7, 17],
        r"$\it{Sparse\ vegetation}$": [20]
    }

    box_width = 0.3

    # Custom colors for box1
    shrub_boxs = {
        "box": "#969696",
        "whisker": "#969696",
        "cap": "#969696",
        "median": "#969696",
        "flier": "#969696"
    }

    # Custom colors for box2
    veg_boxs = {
        "box": "#212529",
        "whisker": "#212529",
        "cap": "#212529",
        "median": "#212529",
        "flier": "#212529"
    }

    for n, var in enumerate(pred_vars):

        # Integer division
        row = n // ncols
        # Division Remainder
        col = n % ncols

        # Split between shrub and trees (and sparse veg)
        for i, (_, lbl_groups) in enumerate(bbox_label_groups.items()):
            
            query_str = "code_v1_reclass == {}"
            
            if len(lbl_groups) == 1:
                data = df.query(query_str.format(lbl_groups[0]))[var]

                box = axs[row, col].boxplot(
                    data,
                    positions=[i+1],
                    widths=box_width,
                    vert=False
                    # orientation="horizontal"
                )
                
                set_box_colors(box, veg_boxs)

            else:
                data = df.query(query_str.format(lbl_groups[0]))[var]
                # Shift the two boxplots slightly left and right of
                # the same group to plot both together
                box1 = axs[row, col].boxplot(
                    data,
                    positions=[(i + 1) - box_width / 2],
                    widths=box_width,
                    vert=False
                    # orientation="horizontal"
                )

                data = df.query(query_str.format(lbl_groups[1]))[var]
                box2 = axs[row, col].boxplot(
                    data,
                    positions=[(i+1) + box_width / 2], 
                    widths=box_width,
                    vert=False
                    # orientation="horizontal"
                )

                # Apply colors
                set_box_colors(box1, veg_boxs)
                set_box_colors(box2, shrub_boxs)

        # Now only set one xtick at the group position
        axs[row, col].set_yticks([z + 1 for z in range(len(bbox_label_groups))])
        axs[row, col].set_yticklabels(bbox_label_groups.keys())
        axs[row, col].grid(True)
        axs[row, col].set_title(var)

# %%
bbox_vars = ["acibasi", "shadow", "slope", "dem", "NDVI_spring", "NDVI_summer"]

create_boxplot(dat_without_out.query(dat_queries[1]), bbox_vars, ncols, nrows)

# %%
create_boxplot(dat_without_out.query(dat_queries[2]), bbox_vars, ncols, nrows)

# %%
create_boxplot(dat_without_out.query(dat_queries[3]), bbox_vars, ncols, nrows)

# %% [markdown]
# #### Construct PCA from summer and spring variables

# %%
def reduction(df, columns, suffix):

    # Standardize predictors (mean=0, variance=1) before PCA
    X = StandardScaler().fit_transform(df[columns])

    # Fit PCA with 3 components
    pca = PCA(n_components=3, random_state=42)
    pca.fit(X)

    # Apply PCA transformation to predictors (NumPy array)
    pca_np = pca.transform(X)

    # Create readable names for PCA components
    pca_cols = ['PCA%i' % i for i in range(1, pca.n_components_ + 1)]
    pca_cols = [n + '_' + suffix for n in pca_cols]

    # Convert PCA results into a DataFrame with proper column names
    return pd.DataFrame(pca_np, columns=pca_cols, index=df.index)

version = 2
spring_pcas = reduction(
    dat_without_out.query(dat_queries[version]),
    dat.columns[dat.columns.str.endswith("spring")],
    "spring")
summer_pcas = reduction(
    dat_without_out.query(dat_queries[version]),
    dat.columns[dat.columns.str.endswith("summer")],
    "summer")
global_pcas = reduction(
    dat_without_out.query(dat_queries[version]),
    ["shadow", "dem", "slope"],
    "global")

pcas_df = pd.concat([
    spring_pcas,
    summer_pcas,
    global_pcas,
    dat_without_out.query(dat_queries[version])["code_v1_reclass"]], axis=1)

# %%
create_boxplot(
    pcas_df,
    pcas_df.columns[pcas_df.columns.str.startswith("PCA")], 3, 3)

# %% [markdown]
# ## Collinearity Among Predictor Variables
#
# The correlation between variables was calculated using the `corr` method in pandas.
#
# It was also tested with [SciPy using permutations](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.spearmanr.html), but this approach required considerably more computation time.
#
# > Although the calculation of the p-value does not make strong assumptions about the distributions underlying the samples, it is only accurate for very large samples (>500 observations). For smaller sample sizes, consider using a permutation test.
#
# [^1]: [Visualization of correlation](https://realpython.com/numpy-scipy-pandas-correlation-python/#visualization-of-correlation)
# [^2]: [Detecting Multicollinearity with VIF](https://www.geeksforgeeks.org/detecting-multicollinearity-with-vif-python/)
# [^3]: [How to Test Multicollinearity](https://www.statology.org/multicollinearity-in-python/)
# [^4]: [Plot Correlation Matrix Using pandas](https://stackoverflow.com/a/50703596/23551600)

# %%
corr_cols = (
    dat.columns.str.endswith("summer")
    | dat.columns.str.endswith("spring")
    | dat.columns.isin(["shadow", "slope", "dem"])
)
corr = (dat_without_out
    .query(dat_queries[3])
    .loc[:, corr_cols]
    .corr(method='spearman')
)
corr.style.background_gradient(
    cmap='coolwarm',
    vmin=-1,
    vmax=1).format(precision=2)
# Out:
# <style type="text/css">
# #T_8efb7_row0_col0, #T_8efb7_row1_col1, #T_8efb7_row2_col2, #T_8efb7_row3_col3, #T_8efb7_row4_col4, #T_8efb7_row5_col5, #T_8efb7_row6_col6, #T_8efb7_row7_col7, #T_8efb7_row8_col8, #T_8efb7_row9_col9, #T_8efb7_row10_col10, #T_8efb7_row11_col11, #T_8efb7_row12_col12, #T_8efb7_row13_col13, #T_8efb7_row14_col14, #T_8efb7_row15_col15, #T_8efb7_row16_col16, #T_8efb7_row17_col17, #T_8efb7_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8efb7_row0_col1, #T_8efb7_row1_col0 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_8efb7_row0_col2, #T_8efb7_row2_col0, #T_8efb7_row7_col10, #T_8efb7_row10_col7, #T_8efb7_row10_col12, #T_8efb7_row12_col10 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_8efb7_row0_col3, #T_8efb7_row3_col0, #T_8efb7_row9_col12, #T_8efb7_row9_col13, #T_8efb7_row12_col9, #T_8efb7_row13_col9 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_8efb7_row0_col4, #T_8efb7_row1_col12, #T_8efb7_row1_col13, #T_8efb7_row4_col0, #T_8efb7_row12_col1, #T_8efb7_row13_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_8efb7_row0_col5, #T_8efb7_row0_col6, #T_8efb7_row2_col12, #T_8efb7_row3_col8, #T_8efb7_row5_col0, #T_8efb7_row6_col0, #T_8efb7_row8_col3, #T_8efb7_row12_col2 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_8efb7_row0_col7, #T_8efb7_row7_col0 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_8efb7_row0_col8, #T_8efb7_row8_col0 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_8efb7_row0_col9, #T_8efb7_row0_col13, #T_8efb7_row9_col0, #T_8efb7_row13_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_8efb7_row0_col10, #T_8efb7_row1_col8, #T_8efb7_row4_col6, #T_8efb7_row6_col4, #T_8efb7_row8_col1, #T_8efb7_row10_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_8efb7_row0_col11, #T_8efb7_row11_col0 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_8efb7_row0_col12, #T_8efb7_row1_col7, #T_8efb7_row7_col1, #T_8efb7_row12_col0 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_8efb7_row0_col14, #T_8efb7_row1_col14, #T_8efb7_row2_col14, #T_8efb7_row14_col0, #T_8efb7_row14_col1, #T_8efb7_row14_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_8efb7_row0_col15, #T_8efb7_row15_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_8efb7_row0_col16, #T_8efb7_row7_col16, #T_8efb7_row8_col16, #T_8efb7_row16_col0, #T_8efb7_row16_col7, #T_8efb7_row16_col8 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_8efb7_row0_col17, #T_8efb7_row17_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_8efb7_row0_col18, #T_8efb7_row12_col17, #T_8efb7_row17_col12, #T_8efb7_row18_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_8efb7_row1_col2, #T_8efb7_row2_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_8efb7_row1_col3, #T_8efb7_row3_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_8efb7_row1_col4, #T_8efb7_row4_col1 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_8efb7_row1_col5, #T_8efb7_row5_col1, #T_8efb7_row17_col18, #T_8efb7_row18_col17 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_8efb7_row1_col6, #T_8efb7_row3_col9, #T_8efb7_row6_col1, #T_8efb7_row6_col9, #T_8efb7_row9_col3, #T_8efb7_row9_col6 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_8efb7_row1_col9, #T_8efb7_row4_col11, #T_8efb7_row9_col1, #T_8efb7_row11_col4 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_8efb7_row1_col10, #T_8efb7_row5_col7, #T_8efb7_row7_col5, #T_8efb7_row10_col1 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_8efb7_row1_col11, #T_8efb7_row11_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_8efb7_row1_col15, #T_8efb7_row15_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_8efb7_row1_col16, #T_8efb7_row11_col17, #T_8efb7_row15_col17, #T_8efb7_row16_col1, #T_8efb7_row17_col11, #T_8efb7_row17_col15 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_8efb7_row1_col17, #T_8efb7_row17_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_8efb7_row1_col18, #T_8efb7_row18_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_8efb7_row2_col3, #T_8efb7_row3_col2, #T_8efb7_row7_col8, #T_8efb7_row8_col7, #T_8efb7_row9_col10, #T_8efb7_row10_col9, #T_8efb7_row12_col13, #T_8efb7_row13_col12 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_8efb7_row2_col4, #T_8efb7_row4_col2 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_8efb7_row2_col5, #T_8efb7_row2_col6, #T_8efb7_row5_col2, #T_8efb7_row6_col2 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_8efb7_row2_col7, #T_8efb7_row7_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_8efb7_row2_col8, #T_8efb7_row3_col7, #T_8efb7_row4_col5, #T_8efb7_row5_col4, #T_8efb7_row6_col7, #T_8efb7_row7_col3, #T_8efb7_row7_col6, #T_8efb7_row8_col2 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_8efb7_row2_col9, #T_8efb7_row2_col10, #T_8efb7_row9_col2, #T_8efb7_row10_col2 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_8efb7_row2_col11, #T_8efb7_row4_col9, #T_8efb7_row9_col4, #T_8efb7_row11_col2 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_8efb7_row2_col13, #T_8efb7_row6_col8, #T_8efb7_row8_col6, #T_8efb7_row13_col2 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_8efb7_row2_col15, #T_8efb7_row15_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_8efb7_row2_col16, #T_8efb7_row3_col16, #T_8efb7_row16_col2, #T_8efb7_row16_col3 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_8efb7_row2_col17, #T_8efb7_row17_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_8efb7_row2_col18, #T_8efb7_row18_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_8efb7_row3_col4, #T_8efb7_row4_col3 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_8efb7_row3_col5, #T_8efb7_row3_col6, #T_8efb7_row5_col3, #T_8efb7_row6_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_8efb7_row3_col10, #T_8efb7_row10_col3 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_8efb7_row3_col11, #T_8efb7_row11_col3 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_8efb7_row3_col12, #T_8efb7_row6_col10, #T_8efb7_row10_col6, #T_8efb7_row12_col3 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_8efb7_row3_col13, #T_8efb7_row5_col10, #T_8efb7_row10_col5, #T_8efb7_row13_col3 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_8efb7_row3_col14, #T_8efb7_row5_col14, #T_8efb7_row6_col14, #T_8efb7_row14_col3, #T_8efb7_row14_col5, #T_8efb7_row14_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_8efb7_row3_col15, #T_8efb7_row15_col3 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_8efb7_row3_col17, #T_8efb7_row17_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_8efb7_row3_col18, #T_8efb7_row18_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_8efb7_row4_col7, #T_8efb7_row7_col4 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_8efb7_row4_col8, #T_8efb7_row8_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_8efb7_row4_col10, #T_8efb7_row7_col11, #T_8efb7_row10_col4, #T_8efb7_row11_col7 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_8efb7_row4_col12, #T_8efb7_row12_col4 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_8efb7_row4_col13, #T_8efb7_row11_col13, #T_8efb7_row13_col4, #T_8efb7_row13_col11 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_8efb7_row4_col14, #T_8efb7_row13_col14, #T_8efb7_row14_col4, #T_8efb7_row14_col13 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_8efb7_row4_col15, #T_8efb7_row15_col4 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_8efb7_row4_col16, #T_8efb7_row16_col4 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_8efb7_row4_col17, #T_8efb7_row17_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_8efb7_row4_col18, #T_8efb7_row18_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_8efb7_row5_col6, #T_8efb7_row6_col5 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_8efb7_row5_col8, #T_8efb7_row8_col5 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_8efb7_row5_col9, #T_8efb7_row9_col5 {
#   b

# %%
pcas_df.corr(method="spearman").style.background_gradient(
    cmap='coolwarm',
    vmin=-1,
    vmax=1).format(precision=2)
# Out:
# <style type="text/css">
# #T_11213_row0_col0, #T_11213_row1_col1, #T_11213_row2_col2, #T_11213_row3_col3, #T_11213_row4_col4, #T_11213_row5_col5, #T_11213_row6_col6, #T_11213_row7_col7, #T_11213_row8_col8, #T_11213_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_11213_row0_col1, #T_11213_row1_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_11213_row0_col2, #T_11213_row2_col0, #T_11213_row4_col9, #T_11213_row9_col4 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_11213_row0_col3, #T_11213_row3_col0 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_11213_row0_col4, #T_11213_row4_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_11213_row0_col5, #T_11213_row5_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_11213_row0_col6, #T_11213_row3_col5, #T_11213_row5_col3, #T_11213_row6_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_11213_row0_col7, #T_11213_row7_col0 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_11213_row0_col8, #T_11213_row7_col8, #T_11213_row8_col0, #T_11213_row8_col7 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_11213_row0_col9, #T_11213_row9_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_11213_row1_col2, #T_11213_row2_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_11213_row1_col3, #T_11213_row3_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_11213_row1_col4, #T_11213_row4_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_11213_row1_col5, #T_11213_row5_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_11213_row1_col6, #T_11213_row2_col3, #T_11213_row3_col2, #T_11213_row6_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_11213_row1_col7, #T_11213_row1_col8, #T_11213_row7_col1, #T_11213_row8_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_11213_row1_col9, #T_11213_row9_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_11213_row2_col4, #T_11213_row4_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_11213_row2_col5, #T_11213_row2_col6, #T_11213_row5_col2, #T_11213_row6_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_11213_row2_col7, #T_11213_row7_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_11213_row2_col8, #T_11213_row3_col7, #T_11213_row4_col8, #T_11213_row7_col3, #T_11213_row8_col2, #T_11213_row8_col4, #T_11213_row8_col9, #T_11213_row9_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_11213_row2_col9, #T_11213_row9_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_11213_row3_col4, #T_11213_row4_col3 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_11213_row3_col6, #T_11213_row6_col3 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_11213_row3_col8, #T_11213_row8_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_11213_row3_col9, #T_11213_row9_col3 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_11213_row4_col5, #T_11213_row5_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_11213_row4_col6, #T_11213_row4_col7, #T_11213_row6_col4, #T_11213_row7_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_11213_row5_col6, #T_11213_row6_col5 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_11213_row5_col7, #T_11213_row7_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_11213_row5_col8, #T_11213_row8_col5 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_11213_row5_col9, #T_11213_row9_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_11213_row6_col7, #T_11213_row7_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_11213_row6_col8, #T_11213_row8_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_11213_row6_col9, #T_11213_row9_col6 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_11213_row7_col9, #T_11213_row9_col7 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# </style>
# <table id="T_11213">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11213_level0_col0" class="col_heading level0 col0" >PCA1_spring</th>
#       <th id="T_11213_level0_col1" class="col_heading level0 col1" >PCA2_spring</th>
#       <th id="T_11213_level0_col2" class="col_heading level0 col2" >PCA3_spring</th>
#       <th id="T_11213_level0_col3" class="col_heading level0 col3" >PCA1_summer</th>
#       <th id="T_11213_level0_col4" class="col_heading level0 col4" >PCA2_summer</th>
#       <th id="T_11213_level0_col5" class="col_heading level0 col5" >PCA3_summer</th>
#       <th id="T_11213_level0_col6" class="col_heading level0 col6" >PCA1_global</th>
#       <th id="T_11213_level0_col7" class="col_heading level0 col7" >PCA2_global</th>
#       <th id="T_11213_level0_col8" class="col_heading level0 col8" >PCA3_global</th>
#       <th id="T_11213_level0_col9" class="col_heading level0 col9" >code_v1_reclass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11213_level0_row0" class="row_heading level0 row0" >PCA1_spring</th>
#       <td id="T_11213_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_11213_row0_col1" class="data row0 col1" >-0.32</td>
#       <td id="T_11213_row0_col2" class="data row0 col2" >0.22</td>
#       <td id="T_11213_row0_col3" class="data row0 col3" >0.65</td>
#       <td id="T_11213_row0_col4" class="data row0 col4" >-0.04</td>
#       <td id="T_11213_row0_col5" class="data row0 col5" >-0.34</td>
#       <td id="T_11213_row0_col6" class="data row0 col6" >-0.21</td>
#       <td id="T_11213_row0_col7" class="data row0 col7" >-0.01</td>
#       <td id="T_11213_row0_col8" class="data row0 col8" >-0.02</td>
#       <td id="T_11213_row0_col9" class="data row0 col9" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_11213_level0_row1" class="row_heading level0 row1" >PCA2_spring</th>
#       <td id="T_11213_row1_col0" class="data row1 col0" >-0.32</td>
#       <td id="T_11213_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_11213_row1_col2" class="data row1 col2" >-0.09</td>
#       <td id="T_11213_row1_col3" class="data row1 col3" >-0.57</td>
#       <td id="T_11213_row1_col4" class="data row1 col4" >0.14</td>
#       <td id="T_11213_row1_col5" class="data row1 col5" >0.55</td>
#       <td id="T_11213_row1_col6" class="data row1 col6" >0.23</td>
#       <td id="T_11213_row1_col7" class="data row1 col7" >-0.08</td>
#       <td id="T_11213_row1_col8" class="data row1 col8" >-0.08</td>
#       <td id="T_11213_row1_col9" class="data row1 col9" >-0.43</td>
#     </tr>
#     <tr>
#       <th id="T_11213_level0_row2" class="row_heading level0 row2" >PCA3_spring</th>
#       <td id="T_11213_row2_col0" class="data row2 col0" >0.22</td>
#       <td id="T_11213_row2_col1" class="data row2 col1" >-0.09</td>
#       <td id="T_11213_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_11213_row2_col3" class="data row2 col3" >0.23</td>
#       <td id="T_11213_row2_col4" class="data row2 col4" >-0.50</td>
#       <td id="T_11213_row2_col5" class="data row2 col5" >0.05</td>
#       <td id="T_11213_row2_col6" class="data row2 col6" >0.05</td>
#       <td id="T_11213_row2_col7" class="data row2 col7" >-0.02</td>
#       <td id="T_11213_row2_col8" class="data row2 col8" >0.00</td>
#       <td id="T_11213_row2_col9" class="data row2 col9" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_11213_level0_row3" class="row_heading level0 row3" >PCA1_summer</th>
#       <td id="T_11213_row3_col0" class="data row3 col0" >0.65</td>
#       <td id="T_11213_row3_col1" class="data row3 col1" >-0.57</td>
#       <td id="T_11213_row3_col2" class="data row3 col2" >0.23</td>
#       <td id="T_11213_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_11213_row3_col4" class="data row3 col4" >-0.22</td>
#       <td id="T_11213_row3_col5" class="data row3 col5" >-0.21</td>
#       <td id="T_11213_row3_col6" class="data row3 col6" >-0.20</td>
#       <td id="T_11213_row3_col7" class="data row3 col7" >0.01</td>
#       <td id="T_11213_row3_col8" class="data row3 col8" >-0.05</td>
#       <td id="T_11213_row3_col9" class="data row3 col9" >0.44</td>
#     </tr>
#     <tr>
#       <th id="T_11213_level0_row4" class="row_heading level0 row4" >PCA2

# %%
pd.concat([
    spring_pcas,
    summer_pcas,
    dat_without_out[["dem", "slope", "shadow"]]
], axis=1).corr(method="spearman").style.background_gradient(
    cmap='coolwarm',
    vmin=-1,
    vmax=1).format(precision=2)
# Out:
# <style type="text/css">
# #T_78c31_row0_col0, #T_78c31_row1_col1, #T_78c31_row2_col2, #T_78c31_row3_col3, #T_78c31_row4_col4, #T_78c31_row5_col5, #T_78c31_row6_col6, #T_78c31_row7_col7, #T_78c31_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_78c31_row0_col1, #T_78c31_row1_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_78c31_row0_col2, #T_78c31_row2_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_78c31_row0_col3, #T_78c31_row3_col0 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_78c31_row0_col4, #T_78c31_row4_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_78c31_row0_col5, #T_78c31_row5_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_78c31_row0_col6, #T_78c31_row6_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_78c31_row0_col7, #T_78c31_row7_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_78c31_row0_col8, #T_78c31_row8_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_78c31_row1_col2, #T_78c31_row2_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_78c31_row1_col3, #T_78c31_row3_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_78c31_row1_col4, #T_78c31_row4_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_78c31_row1_col5, #T_78c31_row5_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_78c31_row1_col6, #T_78c31_row6_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_78c31_row1_col7, #T_78c31_row7_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_78c31_row1_col8, #T_78c31_row8_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_78c31_row2_col3, #T_78c31_row3_col2 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_78c31_row2_col4, #T_78c31_row4_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_78c31_row2_col5, #T_78c31_row5_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_78c31_row2_col6, #T_78c31_row6_col2, #T_78c31_row6_col7, #T_78c31_row6_col8, #T_78c31_row7_col6, #T_78c31_row8_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_78c31_row2_col7, #T_78c31_row7_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_78c31_row2_col8, #T_78c31_row8_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_78c31_row3_col4, #T_78c31_row4_col3 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_78c31_row3_col5, #T_78c31_row5_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_78c31_row3_col6, #T_78c31_row6_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_78c31_row3_col7, #T_78c31_row7_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_78c31_row3_col8, #T_78c31_row8_col3 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_78c31_row4_col5, #T_78c31_row5_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_78c31_row4_col6, #T_78c31_row6_col4 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_78c31_row4_col7, #T_78c31_row7_col4 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_78c31_row4_col8, #T_78c31_row8_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_78c31_row5_col6, #T_78c31_row6_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_78c31_row5_col7, #T_78c31_row7_col5 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_78c31_row5_col8, #T_78c31_row8_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_78c31_row7_col8, #T_78c31_row8_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# </style>
# <table id="T_78c31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78c31_level0_col0" class="col_heading level0 col0" >PCA1_spring</th>
#       <th id="T_78c31_level0_col1" class="col_heading level0 col1" >PCA2_spring</th>
#       <th id="T_78c31_level0_col2" class="col_heading level0 col2" >PCA3_spring</th>
#       <th id="T_78c31_level0_col3" class="col_heading level0 col3" >PCA1_summer</th>
#       <th id="T_78c31_level0_col4" class="col_heading level0 col4" >PCA2_summer</th>
#       <th id="T_78c31_level0_col5" class="col_heading level0 col5" >PCA3_summer</th>
#       <th id="T_78c31_level0_col6" class="col_heading level0 col6" >dem</th>
#       <th id="T_78c31_level0_col7" class="col_heading level0 col7" >slope</th>
#       <th id="T_78c31_level0_col8" class="col_heading level0 col8" >shadow</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78c31_level0_row0" class="row_heading level0 row0" >PCA1_spring</th>
#       <td id="T_78c31_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_78c31_row0_col1" class="data row0 col1" >-0.32</td>
#       <td id="T_78c31_row0_col2" class="data row0 col2" >0.22</td>
#       <td id="T_78c31_row0_col3" class="data row0 col3" >0.65</td>
#       <td id="T_78c31_row0_col4" class="data row0 col4" >-0.04</td>
#       <td id="T_78c31_row0_col5" class="data row0 col5" >-0.34</td>
#       <td id="T_78c31_row0_col6" class="data row0 col6" >-0.03</td>
#       <td id="T_78c31_row0_col7" class="data row0 col7" >-0.18</td>
#       <td id="T_78c31_row0_col8" class="data row0 col8" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_78c31_level0_row1" class="row_heading level0 row1" >PCA2_spring</th>
#       <td id="T_78c31_row1_col0" class="data row1 col0" >-0.32</td>
#       <td id="T_78c31_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_78c31_row1_col2" class="data row1 col2" >-0.09</td>
#       <td id="T_78c31_row1_col3" class="data row1 col3" >-0.57</td>
#       <td id="T_78c31_row1_col4" class="data row1 col4" >0.14</td>
#       <td id="T_78c31_row1_col5" class="data row1 col5" >0.55</td>
#       <td id="T_78c31_row1_col6" class="data row1 col6" >-0.07</td>
#       <td id="T_78c31_row1_col7" class="data row1 col7" >0.16</td>
#       <td id="T_78c31_row1_col8" class="data row1 col8" >-0.24</td>
#     </tr>
#     <tr>
#       <th id="T_78c31_level0_row2" class="row_heading level0 row2" >PCA3_spring</th>
#       <td id="T_78c31_row2_col0" class="data row2 col0" >0.22</td>
#       <td id="T_78c31_row2_col1" class="data row2 col1" >-0.09</td>
#       <td id="T_78c31_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_78c31_row2_col3" class="data row2 col3" >0.23</td>
#       <td id="T_78c31_row2_col4" class="data row2 col4" >-0.50</td>
#       <td id="T_78c31_row2_col5" class="data row2 col5" >0.05</td>
#       <td id="T_78c31_row2_col6" class="data row2 col6" >-0.02</td>
#       <td id="T_78c31_row2_col7" class="data row2 col7" >0.03</td>
#       <td id="T_78c31_row2_col8" class="data row2 col8" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_78c31_level0_row3" class="row_heading level0 row3" >PCA1_summer</th>
#       <td id="T_78c31_row3_col0" class="data row3 col0" >0.65</td>
#       <td id="T_78c31_row3_col1" class="data row3 col1" >-0.57</td>
#       <td id="T_78c31_row3_col2" class="data row3 col2" >0.23</td>
#       <td id="T_78c31_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_78c31_row3_col4" class="data row3 col4" >-0.22</td>
#       <td id="T_78c31_row3_col5" class="data row3 col5" >-0.21</td>
#       <td id="T_78c31_row3_col6" class="data row3 col6" >-0.01</td>
#       <td id="T_78c31_row3_col7" class="data row3 col7" >-0.19</td>
#       <td id="T_78c31_row3_col8" class="data row3 col8" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_78c31_level0_row4" class="row_heading level0 row4" >PCA2_summer</th>
#       <td id="T_78c31_row4_col0" class="data row4 col0" >-0.04</td>
#       <td id="T_78c31_row4_col1" class="data row4 col1" >0.14</td>
#       <td id="T_78c31_row4_col2" class="data row4 col2" >-0.50</td>
#       <td id="T_78c31_row4_col3" class="data row4 col3" >-0.22</td>
#       <td id="T_78c31_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_78c31_row4_col5" class="data row4 col5" >-0.07</td>
#       <td id="T_78c31_row4_col6" class="data row4 col6" >0.11</td>
#       <td id="T_78c31_row4_col7" class="data row4 col7" >0.10</td>
#       <td id="T_78c31_row4_col8" class="data row4 col8" >-0.06</td>
#     </tr>
#     <tr>
#       <th id="T_78c31_level0_row5" class="row_heading level0 row5" >PCA3_summer</th>
#       <td id="T_78c31_row5_col0" class="data row5 col0" >-0.34</td>
#       <td id="T

# %% [markdown]
# ### Variance Inflation Factor
#
# > [...] sequentially drop the covariate with the highest VIF, recalculate the VIFs and repeat this process until all VIFs are smaller than a pre-selected threshold. Montgomery & Peck (1992) used a value of 10, but a more stringent approach is to use values as low as 3 as we did here. High, or even moderate, collinearity is especially problematic when ecological signals are weak. In that case, even a VIF of 2 may cause nonsignificant parameter estimates, compared to the situation without collinearity.
#
#
#
# https://stackoverflow.com/q/42658379/23551600

# %%
def compute_vifs(df):
    return pd.Series(np.linalg.inv(df.to_numpy()).diagonal(), 
                 index=df.columns, 
                 name='VIF')

def best_predictors(df, dat_query, threshold = 3):
    """Remove variables with the highest VIF one by one until anyone are higher than threshold"""
    corr_cols = (
        df.columns.str.endswith("summer")
        | df.columns.str.endswith("spring")
        | df.columns.isin(["shadow", "slope", "dem"])
    )

    corr = df.query(dat_query).loc[:, corr_cols].corr(method='spearman')
    # Compute VIFs for the first time
    vif = compute_vifs(corr)

    # Create a copy of the dataframe to remove invalid variables
    new_df = corr.copy()

    while vif.max() > threshold:
        # Remove the predictor with the maximum value
        max_vif_idx = vif.idxmax()
        new_df = new_df.drop(max_vif_idx).drop(max_vif_idx, axis=1)
        # Recompute vif values
        vif = compute_vifs(new_df)

    return vif

# %%
print(best_predictors(dat_without_out, dat_queries[1]))
# Out:
# coastal_spring    2.207795
# nir_spring        2.405126
# coastal_summer    1.932859
# nir_summer        1.879750
# dem               1.062753
# shadow            1.155393
# slope             1.155857
# Name: VIF, dtype: float64

# %%
print(best_predictors(dat_without_out, dat_queries[2]))
# Out:
# coastal_spring    2.124077
# nir_spring        2.228271
# swir2_spring      2.359162
# coastal_summer    1.613647
# nir_summer        1.684085
# dem               1.021430
# shadow            1.169923
# slope             1.130247
# Name: VIF, dtype: float64

# %%
print(best_predictors(dat_without_out, dat_queries[3]))
# Out:
# coastal_spring    2.248135
# nir_spring        2.289822
# swir2_spring      2.682565
# coastal_summer    1.770488
# nir_summer        1.817448
# dem               1.040675
# shadow            1.177611
# slope             1.121349
# Name: VIF, dtype: float64
